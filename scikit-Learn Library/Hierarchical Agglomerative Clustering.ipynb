# %%
# problem Statement:
"""You are the data scientist at a retail company, the marketing 
team is looking to optimize their promotional campaigns by targeting
specific cutomer segments. The goal is to identify groups of customers
based on their demographic information such as age, income, and spending score. """
# Solution: Agglomerative Hierarchical Clustering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

# %%
#data Creation
np.random.seed(42)
data = pd.DataFrame({'Age': np.random.randint(18,65,100),
                     'Income': np.random.randint(30000, 100000,100), 
                     "SpendingScore": np.random.randint(1,100,100)})

# %%
scaler = StandardScaler() # for Standardization
scaled_data = scaler.fit_transform(data)

# %%
clustering = AgglomerativeClustering(n_clusters = 3, metric = 'euclidean', linkage = 'ward')
data['Cluster'] = clustering.fit_predict(scaled_data)

# %%
plt.scatter(data["Income"], data["SpendingScore"], c = data["Cluster"], cmap = "viridis" )
plt.xlabel('Income')
plt.ylabel('SpendingScore')
plt.title('customer Segmentation')
plt.show()

# %%
new_customer = pd.DataFrame({"Age": [30],
                            "Income": [70000],
                            "SpendingScore": [70]},
                           {"Age": [50],
                            "Income": [60000],
                            "SpendingScore": [80]},
                           {"Age": [60],
                            "Income": [90000],
                            "SpendingScore": [70]},) 
scaled_new_customer = scaler.transform(new_customer)
predicted_cluster = clustering.fit_predict(scaled_new_customer)
print(f"The new customers predicted cluster is : {predicted_cluster}")
# Out:
# The new customers predicted cluster is : [2 1 0]

# %%
new_customer
# Out:
#    Age  Income  SpendingScore
# 0   30   70000             70
# 1   50   80000             80
